# %%
# Global variables

import random # for shuffling

suits = ('Hearts','Diamond','Spade','Club')

ranks = ('Two','Three','Four','Five','Six','Seven',
        
        'Eight','Nine','Ten','Jack','Queen','King','Ace'
         
         
        )

value = {'Two':2,'two':2,'Three':3,'three':3,'Four':4,'four':4,'Five':5,'five':5,'Six':6,'six':6,'Seven':7,'seven':7,
        
        'Eight':8,'eight':8,'Nine':9,'nine':9,'Ten':10,'Jack':11,'jack':11,'Queen':12,'queen':12,'King':13,'king':13,'Ace':14,
         
         'ace':14
        
        }

# %%
class card:
    
    def __init__(self,suit,rank):
        
        self.suit = suit
        self.rank = rank
        self.value = value[rank]
        
    def __str__(self):
        
        return self.rank + " of " + self.suit

# %%
class Deck:
    
    def __init__(self):
        
        self.all_cards = []   # bcoz at very start of game there is no cards so to get 52 cards call card class to holds all cards here
        
        for suit in suits:
            for rank in ranks:
                
                # creat the card object
                created_card = card(suit,rank)
                
                self.all_cards.append(created_card)
                
    # see indentation 
    
    def shuffle(self):
        random.shuffle(self.all_cards)   # so here we don't have to return bcoz it will not return anything we have to just shuufle cards
        
    def deal_one(self):
        
        return self.all_cards.pop()

# %%
class Player:
    
    def __init__(self,name):
        
        self.name = name
        self.all_cards = []
        
    def remove_one(self):
        
        return self.all_cards.pop(0)     # pop oth position index object bcoz top is at left
    
    def add_cards(self,new_cards):
        
        if type(new_cards) == type([]):
            # list oof multiple cards objects
            self.all_cards.extend(new_cards)
        else:
            # list of single card object
            self.all_cards.append(new_cards)
            
    def __str__(self):
        return f'Player {self.name} has {len(self.all_cards)} cards'

# %%
new_deck = Deck()

# %%
len(new_deck.all_cards)
# Out:
# 52

# %%
# Game setup

# players
player_one = Player("one")
player_two = Player("two")

#Deck + shuffle
new_deck = Deck()
new_deck.shuffle()

#split cards to each palyer (26+26=52)
for x in range(26):
    player_one.add_cards(new_deck.deal_one())
    player_two.add_cards(new_deck.deal_one())

# %%
len(player_one.all_cards)
# Out:
# 26

# %%
len(player_two.all_cards)
# Out:
# 26

# %%
print(player_one)
# Out:
# Player one has 26 cards

# %%
print(player_two)
# Out:
# Player two has 26 cards

# %% [raw]
# game_on = True
#
#
# round_num = 0
# while game_on:
#
#     round_num +=1
#     print(f'Round {round_num}')
#
#     # check to see whether player is out of cards
#
#     if len(player_one.all_cards) == 0:
#         print("One lost the game! Two wins! ")
#         game_on = False
#         break
#
#     if len(player_two.all_cards) == 0:
#         print("Two lost the game! One wins! ")
#         game_on = False
#         break
#
#     # Otherwise the game is still going on
#
#     # Start a new round and reset current cards "on the table"
#
#     player_one_cards = []           # here we take new empty variable to check priority but before that we have to remove top card to check and add in this variable
#     player_one_cards.append(player_one.remove_one())
#
#     player_two_cards = []            # same here remove one card from player_two and comapre this variable about its priority
#     player_two_cards.append(player_two.remove_one())
#
#     at_war = True
#
#     while at_war:
#
#         if player_one_cards[-1].value > player_two_cards[-1].value:
#
#             # player_one gets all cards
#             player_one.add_cards(player_one_cards)
#             player_one.add_cards(player_two_cards)
#
#         elif player_one_cards[-1].value < player_two_cards[-1].value:
#
#             # palyer_two gets all cards
#             player_one.add_cards(player_two_cards)
#             player_two.add_cards(player_one_cards)
#
#         else:
#             print("War!")
#
#             if len(player_one.all_cards) < 5:                   # here u can take length other than 5 but more the lenght here
#                                                                 # comparisions get less so shorter the game if higher the length
#                                                                 # so take higher length always to become shorter the game
#                 print("Player One unable to War!")
#                 print("player Two wins!")
#                 game_on = False
#                 break
#
#             elif len(player_two.all_cards) < 5:
#
#                 print("player two unable to war!")
#                 print("player One wins!")
#                 game_on = False
#                 break
#
#             else:
#
#                 for num in range(5):
#                     player_one_cards.append(player_one.remove_one())
#                     player_two_cards.append(player_two.remove_one())

# %%
# this above my logic is not running so refer jose logic from notes see next and shuufle everythime the game otherwise it will give

# alternatively player 1 wins so shuffle everytime for new game i.e run game setup everytime

# %%
game_on = True

# %%
round_num = 0
while game_on:
    
    round_num += 1
    print(f"Round {round_num}")
    
    # Check to see if a player is out of cards:
    if len(player_one.all_cards) == 0:
        print("Player One out of cards! Game Over")
        print("Player Two Wins!")
        game_on = False
        break
        
    if len(player_two.all_cards) == 0:
        print("Player Two out of cards! Game Over")
        print("Player One Wins!")
        game_on = False
        break
    
    # Otherwise, the game is still on!
    
    # Start a new round and reset current cards "on the table"
    player_one_cards = []
    player_one_cards.append(player_one.remove_one())
    
    player_two_cards = []
    player_two_cards.append(player_two.remove_one())
    
    at_war = True

    while at_war:


        if player_one_cards[-1].value > player_two_cards[-1].value:

            # Player One gets the cards
            player_one.add_cards(player_one_cards)
            player_one.add_cards(player_two_cards)
            
            
            # No Longer at "war" , time for next round
            at_war = False
        
        # Player Two Has higher Card
        elif player_one_cards[-1].value < player_two_cards[-1].value:

            # Player Two gets the cards
            player_two.add_cards(player_one_cards)
            player_two.add_cards(player_two_cards)
            
            # No Longer at "war" , time for next round
            at_war = False

        else:
            print('WAR!')
            # This occurs when the cards are equal.
            # We'll grab another card each and continue the current war.
            
            # First check to see if player has enough cards
            
            # Check to see if a player is out of cards:
            if len(player_one.all_cards) < 5:
                print("Player One unable to play war! Game Over at War")
                print("Player Two Wins! Player One Loses!")
                game_on = False
                break

            elif len(player_two.all_cards) < 5:
                print("Player Two unable to play war! Game Over at War")
                print("Player One Wins! Player One Loses!")
                game_on = False
                break
            # Otherwise, we're still at war, so we'll add the next cards
            else:
                for num in range(5):
                    player_one_cards.append(player_one.remove_one())
                    player_two_cards.append(player_two.remove_one())
# Out:
# Round 1
# Round 2
# Round 3
# Round 4
# Round 5
# Round 6
# Round 7
# WAR!
# Round 8
# Round 9
# WAR!
# Round 10
# WAR!
# Round 11
# Round 12
# Round 13
# Round 14
# WAR!
# Round 15
# Round 16
# WAR!
# Round 17
# Round 18
# Round 19
# Round 20
# WAR!
# Round 21
# Round 22
# Round 23
# Round 24
# Round 25
# Round 26
# Round 27
# Round 28
# Round 29
# Round 30
# WAR!
# Round 31
# Round 32
# Round 33
# Round 34
# Round 35
# WAR!
# Round 36
# Round 37
# Round 38
# Round 39
# Round 40
# Round 41
# Round 42
# Round 43
# Round 44
# Round 45
# Round 46
# Round 47
# Round 48
# Round 49
# Round 50
# Round 51
# Round 52
# Round 53
# Round 54
# Round 55
# Round 56
# WAR!
# Round 57
# Round 58
# Round 59
# Round 60
# Round 61
# Round 62
# Round 63
# Round 64
# Round 65
# Round 66
# Round 67
# Round 68
# Round 69
# Round 70
# Round 71
# Round 72
# Round 73
# Round 74
# Round 75
# Round 76
# Round 77
# Round 78
# Round 79
# Round 80
# Round 81
# Round 82
# Round 83
# Round 84
# Round 85
# Round 86
# ...

# %%
# Game setup

# players
player_one = Player("one")
player_two = Player("two")

#Deck + shuffle
new_deck = Deck()
new_deck.shuffle()

#split cards to each palyer (26+26=52)
for x in range(26):
    player_one.add_cards(new_deck.deal_one())
    player_two.add_cards(new_deck.deal_one())

# %%
game_on = True

# %%
round_num = 0
while game_on:
    
    round_num += 1
    print(f"Round {round_num}")
    
    # Check to see if a player is out of cards:
    if len(player_one.all_cards) == 0:
        print("Player One out of cards! Game Over")
        print("Player Two Wins!")
        game_on = False
        break
        
    if len(player_two.all_cards) == 0:
        print("Player Two out of cards! Game Over")
        print("Player One Wins!")
        game_on = False
        break
    
    # Otherwise, the game is still on!
    
    # Start a new round and reset current cards "on the table"
    player_one_cards = []
    player_one_cards.append(player_one.remove_one())
    
    player_two_cards = []
    player_two_cards.append(player_two.remove_one())
    
    at_war = True

    while at_war:


        if player_one_cards[-1].value > player_two_cards[-1].value:

            # Player One gets the cards
            player_one.add_cards(player_one_cards)
            player_one.add_cards(player_two_cards)
            
            
            # No Longer at "war" , time for next round
            at_war = False
        
        # Player Two Has higher Card
        elif player_one_cards[-1].value < player_two_cards[-1].value:

            # Player Two gets the cards
            player_two.add_cards(player_one_cards)
            player_two.add_cards(player_two_cards)
            
            # No Longer at "war" , time for next round
            at_war = False

        else:
            print('WAR!')
            # This occurs when the cards are equal.
            # We'll grab another card each and continue the current war.
            
            # First check to see if player has enough cards
            
            # Check to see if a player is out of cards:
            if len(player_one.all_cards) < 5:
                print("Player One unable to play war! Game Over at War")
                print("Player Two Wins! Player One Loses!")
                game_on = False
                break

            elif len(player_two.all_cards) < 5:
                print("Player Two unable to play war! Game Over at War")
                print("Player One Wins! Player One Loses!")
                game_on = False
                break
            # Otherwise, we're still at war, so we'll add the next cards
            else:
                for num in range(5):
                    player_one_cards.append(player_one.remove_one())
                    player_two_cards.append(player_two.remove_one())
# Out:
# Round 1
# Round 2
# Round 3
# WAR!
# Round 4
# Round 5
# Round 6
# Round 7
# Round 8
# Round 9
# Round 10
# Round 11
# Round 12
# Round 13
# Round 14
# Round 15
# Round 16
# Round 17
# WAR!
# Round 18
# Round 19
# Round 20
# Round 21
# Round 22
# WAR!
# Round 23
# Round 24
# Round 25
# Round 26
# Round 27
# Round 28
# Round 29
# Round 30
# Round 31
# Round 32
# Round 33
# Round 34
# Round 35
# Round 36
# Round 37
# Round 38
# Round 39
# Round 40
# Round 41
# Round 42
# Round 43
# Round 44
# WAR!
# Round 45
# Round 46
# Round 47
# Round 48
# Round 49
# Round 50
# Round 51
# Round 52
# Round 53
# Round 54
# Round 55
# Round 56
# Round 57
# Round 58
# Round 59
# Round 60
# Round 61
# Round 62
# Round 63
# Round 64
# Round 65
# Round 66
# Round 67
# Round 68
# Round 69
# Round 70
# Round 71
# Round 72
# Round 73
# Round 74
# Round 75
# Round 76
# Round 77
# Round 78
# Round 79
# Round 80
# Round 81
# Round 82
# Round 83
# Round 84
# WAR!
# Round 85
# WAR!
# Round 86
# Round 87
# ...

# %%
# so we have run two times and see result there is war many time aslo and also one ti,e player 1 wins and player 2 wins one time
# that means code is wrking perfect
