# %%
import requests

# %%
import bs4

# %% [raw]
# # if u go any wkipedia right click on that click on view page source it gives html code and if if slect any part of wekipedia content and right click and if u select inspect it gives all infor about that is terms of html and css so to grab some part to download images and save and to use wherever we want python web scraping helps here lot

# %%
result = requests.get("http://www.boltiot.com")

# %%
type(result)
# Out:
# requests.models.Response

# %%
# it means it gives responses whtever store in boltiot.com

# %%
result.text
# Out:
# '<!doctype html><!--[if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="en" > <![endif]--><!--[if IE 7]>    <html class="no-js lt-ie9 lt-ie8" lang="en" >        <![endif]--><!--[if IE 8]>    <html class="no-js lt-ie9" lang="en" >               <![endif]--><!--[if gt IE 8]><!--><html class="no-js" lang="en"><!--<![endif]--><head>\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n    <meta name="author" content="Bolt IoT (Inventrom Private Limited)">\n    <meta name="description" content="An Internet of Things Platform for developers.">\n    <meta name="generator" content="HubSpot">\n    <title>Bolt : IoT Platform</title>\n    <link rel="shortcut icon" href="https://www.boltiot.com/hubfs/Bolt_IoT_GreenGray_vertical-2.png">\n    \n\n    <script src="/hs/hsstatic/jquery-libs/static-1.1/jquery/jquery-1.7.1.js"></script>\n<script>hsjQuery = window[\'jQuery\'];</script>\n    <meta property="og:description" content="An Internet of Thing
# ...

# %% [raw]
# # so see we have grab all html code of boltiot.com website by text in built method of requests lib

# %% [raw]
# #  but it looks weird way means it is not easy to readable this content so to see proper way that what html tags ,css code,css class and all that we have beautifulsoup method of bs4 lib see next

# %%
soup = bs4.BeautifulSoup(result.text,"lxml")

# in lxml it is l not 1 we have also install lxml lib

# %%
soup
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="en" > <![endif]--><!--[if IE 7]>    <html class="no-js lt-ie9 lt-ie8" lang="en" >        <![endif]--><!--[if IE 8]>    <html class="no-js lt-ie9" lang="en" >               <![endif]--><!--[if gt IE 8]><!--><html class="no-js" lang="en"><!--<![endif]--><head>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="Bolt IoT (Inventrom Private Limited)" name="author"/>
# <meta content="An Internet of Things Platform for developers." name="description"/>
# <meta content="HubSpot" name="generator"/>
# <title>Bolt : IoT Platform</title>
# <link href="https://www.boltiot.com/hubfs/Bolt_IoT_GreenGray_vertical-2.png" rel="shortcut icon"/>
# <script src="/hs/hsstatic/jquery-libs/static-1.1/jquery/jquery-1.7.1.js"></script>
# <script>hsjQuery = window['jQuery'];</script>
# ...

# %% [raw]
# # so see this above o/p of html code looking same as boltiot.come html compare it is looks beautiful way now its easy to readable

# %%
# see ss of comparable html code in python folder

# %% [raw]
# # so if we want to grsb title or any tag present  in this html code see how?

# %%
soup.select('title')
# Out:
# [<title>Bolt : IoT Platform</title>]

# %% [raw]
# # see boltiot webpage has title given as Bolt : IoT Platform
#
# it return in list bcoz it may have multiple titles so it gives as a list

# %%
# grab pargraphs
# pass tags 
soup.select('p')  # p is a tag to represent paragraphs
# Out:
# [<p class="secondary-header"><span class="section-subheader" id="hs_cos_wrapper_subheader">Bolt IoT platform gives you the capability to control your devices and collect data from IoT devices safely and securely no matter where you are. Get actionable insights by deploying machine learning algorithms with just a few clicks to detect anomalies as well as predict sensor values.</span></p>,
#  <p style="line-height: 1;"> </p>,
#  <p style="line-height: 1;"> </p>,
# ...

# %% [raw]
# # so in this u can search/ grab anything from webpage bu passign tag

# %%
soup.select('h1')
# Out:
# [<h1>How does it work?</h1>,
#  <h1>
#
#
#
#
#
#
#
#
#
#  Sign In</h1>,
#  <h1>Become a partner</h1>,
#  <h1>Our reseller partners</h1>,
#  <h1>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Features</h1>,
#  <h1>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Blog</h1>,
#  <h1>
#
#
#
#
#
#
#
#
#
#  What can you build with Bolt ?</h1>]

# %% [raw]
# # but instead of returning list with tags if we want actual text then see

# %%
soup.select('title')
# Out:
# [<title>Bolt : IoT Platform</title>]

# %%
# bcoz of list we have to give indexing
soup.select('title')[0].getText()
# Out:
# 'Bolt : IoT Platform'

# %%
# so see it return only tile

# %%
site_paragraphs = soup.select('p')

# %%
site_paragraphs
# Out:
# [<p class="secondary-header"><span class="section-subheader" id="hs_cos_wrapper_subheader">Bolt IoT platform gives you the capability to control your devices and collect data from IoT devices safely and securely no matter where you are. Get actionable insights by deploying machine learning algorithms with just a few clicks to detect anomalies as well as predict sensor values.</span></p>,
#  <p style="line-height: 1;"> </p>,
#  <p style="line-height: 1;"> </p>,
# ...

# %% [raw]
# # it return all paragraphs but if u want particular paragraph let say 1st para see how to grab that

# %%
site_paragraphs[0]
# Out:
# <p class="secondary-header"><span class="section-subheader" id="hs_cos_wrapper_subheader">Bolt IoT platform gives you the capability to control your devices and collect data from IoT devices safely and securely no matter where you are. Get actionable insights by deploying machine learning algorithms with just a few clicks to detect anomalies as well as predict sensor values.</span></p>

# %%
type(site_paragraphs[0])
# Out:
# bs4.element.Tag

# %% [raw]
# # sosee this is actually a specialized beautifulsoup object which is why i can do something like call .getText so it is not type of string

# %%
site_paragraphs[0].getText()
# Out:
# 'Bolt IoT platform gives you the capability to control your devices and collect data from IoT devices safely and securely no matter where you are. Get actionable insights by deploying machine learning algorithms with just a few clicks to detect anomalies as well as predict sensor values.'

# %% [markdown]
# # Grabbing an class tags

# %% [raw]
# Syntax to pass to the .select() method
#
# Match Results
#
# soup.select('div'):
#
# All elements with the <div> tag
#
# soup.select('#some_id'):
#
# The HTML element containing the id attribute of some_id
#
# soup.select('.notice'):
#
# All the HTML elements with the CSS class named notice
#
# soup.select('.some_class'):
# Elements containing class = some_class
#
# soup.select('div span'):
#
# Any elements named <span> that are within an element named <div>
#
# soup.select('div > span'):
#
# Any elements named <span> that are directly within an element named <div>, with no other element in between
